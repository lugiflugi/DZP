# %% [markdown]
# ### This file needs to be run only once to create the CSV files for each country

# %%
import geonamescache
import csv

gc = geonamescache.GeonamesCache()

# Fetch all countries from geonamescache
countries = gc.get_countries()

# Fetch City data with the ISO codes of all countries in Europe
european_country_codes = ['AL', 'AD', 'AM', 'AT', 'AZ', 'BY', 'BE', 'BA', 'BG', 'HR', 'CY', 'CZ', 'DK', 'EE', 'FO', 'FI', 'FR', 'GE', 'DE', 'GI', 'GR', 'GL', 'GG', 'HU', 'IS',
                          'IE', 'IM', 'IT', 'JE', 'KZ', 'XK', 'LV', 'LT', 'LU', 'MK', 'MT', 'MD', 'MC', 'ME', 'NL', 'NO', 'PL', 'PT', 'RO', 'RU', 'RS', 'SK', 'SI', 'ES', 'SE', 'CH', 'UA', 'GB', 'TR', 'UZ']
# Fetch all cities from geonamescache
cities = gc.get_cities()

# %%
cities
# Out:
# {'3040051': {'geonameid': 3040051,
#   'name': 'les Escaldes',
#   'latitude': 42.50729,
#   'longitude': 1.53414,
#   'countrycode': 'AD',
#   'population': 15853,
#   'timezone': 'Europe/Andorra',
#   'admin1code': '08',
#   'alternatenames': ["Ehskal'des-Ehndzhordani",
#    'Escaldes',
#    'Escaldes-Engordany',
#    'Les Escaldes',
#    'esukarudesu=engorudani jiao qu',
#    'lai sai si ka er de-en ge er da',
#    'Эскальдес-Энджордани',
#    'エスカルデス＝エンゴルダニ教区',
#    '萊塞斯卡爾德-恩戈爾達',
#    '萊塞斯卡爾德－恩戈爾達']},
#  '3041563': {'geonameid': 3041563,
#   'name': 'Andorra la Vella',
#   'latitude': 42.50779,
#   'longitude': 1.52109,
#   'countrycode': 'AD',
#   'population': 20430,
#   'timezone': 'Europe/Andorra',
#   'admin1code': '07',
#   'alternatenames': ['ALV',
#    'Ando-la-Vyey',
#    'Andora',
#    'Andora la Vela',
#    'Andora la Velja',
#    "Andora lja Vehl'ja",
#    'Andoro Malnova',
#    'Andorra',
#    'Andorra Tuan',
#    'Andorra a Vella',
#    'Andorra la Biella',
# ...

# %%
countries
# Out:
# {'AD': {'geonameid': 3041565,
#   'name': 'Andorra',
#   'iso': 'AD',
#   'iso3': 'AND',
#   'isonumeric': 20,
#   'fips': 'AN',
#   'continentcode': 'EU',
#   'capital': 'Andorra la Vella',
#   'areakm2': 468,
#   'population': 77006,
#   'tld': '.ad',
#   'currencycode': 'EUR',
#   'currencyname': 'Euro',
#   'phone': '376',
#   'postalcoderegex': '^(?:AD)*(\\d{3})$',
#   'languages': 'ca',
#   'neighbours': 'ES,FR'},
#  'AE': {'geonameid': 290557,
#   'name': 'United Arab Emirates',
#   'iso': 'AE',
#   'iso3': 'ARE',
#   'isonumeric': 784,
#   'fips': 'AE',
#   'continentcode': 'AS',
#   'capital': 'Abu Dhabi',
#   'areakm2': 82880,
#   'population': 9630959,
#   'tld': '.ae',
#   'currencycode': 'AED',
#   'currencyname': 'Dirham',
#   'phone': '971',
#   'postalcoderegex': '',
#   'languages': 'ar-AE,fa,en,hi,ur',
#   'neighbours': 'SA,OM'},
#  'AF': {'geonameid': 1149361,
#   'name': 'Afghanistan',
#   'iso': 'AF',
#   'iso3': 'AFG',
#   'isonumeric': 4,
#   'fips': 'AF',
# ...

# %%
# Get European cities with population greater than 10,000
european_cities = []
for city_id, city_data in cities.items():
    # fetch all cities with greater than 10,000 population
    if city_data['countrycode'] in european_country_codes and city_data['population'] > 10000:
        # fetch city name, country code, latitude, longitude, population and geonameid
        city_name = city_data['name']
        city_country = city_data['countrycode']
        city_lat = city_data['latitude']
        city_lon = city_data['longitude']
        city_pop = city_data['population']
        city_id = city_data['geonameid']
        # append the city data to the list of european cities
        european_cities.append({'name': city_name, 'latitude': city_lat, 'longitude': city_lon, 'country': city_country, 'population': city_pop, 'id': city_id})

# %%
# Save the European cities in separate CSV files for each country
for country_code in european_country_codes:
    country_cities = [city for city in european_cities if city['country'] == country_code]
    if country_cities:
        file_name = f"{country_code}_Cities.csv"
        with open(file_name, 'w', newline='', encoding='utf-8') as csvfile:
            # set column names
            fieldnames = ['name', 'latitude', 'longitude', 'country', 'population', 'id']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(country_cities)
            # print the file name for each country that has been created
            print(f"CSV file for {country_code} has been created.")
# Out:
# CSV file for AL has been created.
# CSV file for AD has been created.
# CSV file for AM has been created.
# CSV file for AT has been created.
# CSV file for AZ has been created.
# CSV file for BY has been created.
# CSV file for BE has been created.
# CSV file for BA has been created.
# CSV file for BG has been created.
# CSV file for HR has been created.
# CSV file for CY has been created.
# CSV file for CZ has been created.
# CSV file for DK has been created.
# CSV file for EE has been created.
# CSV file for FO has been created.
# CSV file for FI has been created.
# CSV file for FR has been created.
# CSV file for GE has been created.
# CSV file for DE has been created.
# CSV file for GI has been created.
# CSV file for GR has been created.
# CSV file for GL has been created.
# CSV file for GG has been created.
# CSV file for HU has been created.
# CSV file for IS has been created.
# CSV file for IE has been created.
# CSV file for IM has been created.
# ...
