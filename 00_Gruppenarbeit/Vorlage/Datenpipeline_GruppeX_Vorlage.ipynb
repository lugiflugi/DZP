# %% [markdown]
# ## Gruppe X - Titel der Arbeit

# %% [markdown]
# ### Fragestellung und Datenquelle

# %% [markdown]
# Erklärung der Fragestellung..
#
# Eklärung, welche Daten aus welchem API

# %% [markdown]
# ### Datenpipeline

# %%
## Code, Kommentare, Code-Dokumentation

# %% [markdown]
# Erklärung der Pipeline

# %% [markdown]
# ### Reflektion

# %% [markdown]
# Mitglied 1:
# - Was hat gut funktioniert?
# - Was hat nicht gut funktioniert?
# - Was würdest du beim nächsten Mal anders machen?
# - Was hast du gelernt?
# - Was war die grösste Herausforderung?
# - usw.

# %% [markdown]
# Mitglied 2:
# - Was hat gut funktioniert?
# - Was hat nicht gut funktioniert?
# - Was würdest du beim nächsten Mal anders machen?
# - Was hast du gelernt?
# - Was war die grösste Herausforderung?
# - usw.

# %% [markdown]
# Mitglied 3:
# - Was hat gut funktioniert?
# - Was hat nicht gut funktioniert?
# - Was würdest du beim nächsten Mal anders machen?
# - Was hast du gelernt?
# - Was war die grösste Herausforderung?
# - usw.
