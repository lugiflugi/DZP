# %% [markdown]
# # Peer-Feebacks der Präsentationen (Gruppe X)

# %% [markdown]
# ## Peer-Feedback Gruppe W

# %% [markdown]
# ---
#
# ## Peer-Feedback Gruppe Y

# %% [markdown]
# ---
# ## Peer-Feedback Gruppe Z
